# %%
import os
import csv
import pandas
from collections import Counter

# %%
pandas.__version__
# Out:
# '0.15.2'

# %%
DATA_DIR = "/Users/brian/code/bible/data"
OUTPUT_DIR = "/Users/brian/code/bible/output"
TEXT_PATH = os.path.join(DATA_DIR, "bible-corpus/t_kjv.csv")
QUOTATION_PATH = os.path.join(DATA_DIR, "bible-ot-nt.tsv")
ABBREV_PATH = os.path.join(DATA_DIR, "bible-corpus/key_abbreviations_english.csv")

BOOK_DF_PATH = os.path.join(OUTPUT_DIR, "books_summary.csv")
QUOTATIONS_OUT_PATH = os.path.join(OUTPUT_DIR, "quotations.csv")
QUOTATIONS_OT_OUT_PATH = os.path.join(OUTPUT_DIR, "quotations_ot.csv")
QUOTATIONS_TEXT_OUT_PATH = os.path.join(OUTPUT_DIR, "quotations_text.csv")
QUOTATIONS_TEXT_OT_OUT_PATH = os.path.join(OUTPUT_DIR, "quotations_ot_text.csv")

# %%
book_df = pandas.read_csv(BOOK_DF_PATH)
abbrev_df = pandas.read_csv(ABBREV_PATH)
quotation_df = pandas.read_csv(QUOTATION_PATH, sep="\t")

# Have to add some extra rows to the abbreviation dataframe
abbrev_df = abbrev_df.append({"id": 343, "a": "De", "b": 5, "p": 0}, ignore_index=True)
abbrev_df = abbrev_df.append({"id": 344, "a": "Lu", "b": 42, "p": 0}, ignore_index=True)
abbrev_df = abbrev_df.append({"id": 345, "a": "Joh", "b": 43, "p": 0}, ignore_index=True)

# %%
book_lookup = dict(zip(book_df["b"], book_df["name"]))
abbrev_to_id = dict(zip(abbrev_df["a"], abbrev_df["b"]))
abbrev_to_book = dict(zip(abbrev_df["a"], [book_lookup[i] for i in abbrev_df["b"]]))

# %%
passages = quotation_df["NT"]
abbrevs, locations = [list(tup) for tup in zip(*[tuple(passage.split(" ")) for passage in passages])]
chapters, verses = [list(tup) for tup in zip(*[tuple(location.split(":")) for location in locations])]
chapters = [int(c) for c in chapters]
# select just the first verse for simplicity
verses = [int(vs.split(",")[0].split("-")[0]) for vs in verses]
books = [abbrev_to_book[abbrev] for abbrev in abbrevs]
book_ids = [abbrev_to_id[abbrev] for abbrev in abbrevs]

# %%
quotation_df["nt_b"] = book_ids
quotation_df["nt_book"] = books
quotation_df["nt_c"] = chapters
quotation_df["nt_v"] = verses

# %%
passages = quotation_df["OT"]
abbrevs, locations = [list(tup) for tup in zip(*[tuple(passage.split(" ")) for passage in passages])]
chapters, verses = [list(tup) for tup in zip(*[tuple(location.split(":")) for location in locations])]
chapters = [int(c) for c in chapters]
# select just the first verse for simplicity
verses = [int(vs.split(",")[0].split("-")[0]) for vs in verses]
books = [abbrev_to_book[abbrev] for abbrev in abbrevs]
book_ids = [abbrev_to_id[abbrev] for abbrev in abbrevs]

# %%
quotation_df["ot_b"] = book_ids
quotation_df["ot_book"] = books
quotation_df["ot_c"] = chapters
quotation_df["ot_v"] = verses

# %%
quotation_df = quotation_df[["ID", "OT", "ot_book", "ot_b", "ot_c", "ot_v",
                             "NT", "nt_book", "nt_b", "nt_c", "nt_v"]]

# %%
quotation_df
# Out:
#       ID              OT      ot_book  ot_b  ot_c  ot_v              NT  \
# 0      1        Isa 7:14       Isaiah    23     7    14         Mt 1:23
# 1      2         Mic 5:2        Micah    33     5     2          Mt 2:6
# 2      3         Ho 11:1        Hosea    28    11     1         Mt 2:15
# 3      4       Jer 31:15     Jeremiah    24    31    15         Mt 2:18
# 4      5        Isa 40:3       Isaiah    23    40     3          Mt 3:3
# 5      6          De 8:3  Deuteronomy     5     8     3          Mt 4:4
# 6      7     Ps 91:11,12       Psalms    19    91    11          Mt 4:6
# 7      8         De 6:16  Deuteronomy     5     6    16          Mt 4:7
# 8      9         De 6:13  Deuteronomy     5     6    13         Mt 4:10
# 9     10        De 10:20  Deuteronomy     5    10    20         Mt 4:10
# 10    11       Isa 9:1,2       Isaiah    23     9     1      Mt 4:15,16
# 11    12        Isa 42:7       Isaiah    23    42     7      Mt 4:15,16
# 12    13         De 5:17  Deuteronomy     5     5    17         Mt 5:21
# 13    14         De 5:18  Deuteronomy     5     5    18         Mt 5:27
# 14    15        De 19:21  Deuteronomy     5    19    21         Mt 5:38
# 15    16         Ge 17:1      Genesis     1    17     1         Mt 5:48
# 16    17          Ps 6:8       Psalms    19     6     8         Mt 7:23
# 17    18        Isa 53:4       Isaiah    23    53     4         Mt 8:17
# 18    19          Ho 6:6        Hosea    28     6     6         Mt 9:13
# 19    20         Mal 3:1      Malachi    39     3     1        Mt 11:10
# 20    21          Ho 6:6        Hosea    28     6     6         Mt 12:7
# 21    22        Isa 42:1       Isaiah    23    42     1        Mt 12:18
# 22    23      Isa 42:1-4       Isaiah    23    42     1     Mt 12:18-21
# 23    24      Isa 6:9,10       Isaiah    23     6     9        Mt 13:14
# 24    25         Ps 78:2       Psalms    19    78     2        Mt 13:35
# 25    26        Ex 20:12       Exodus     2    20    12         Mt 15:4
# 26    27         De 5:16  Deuteronomy     5     5    16         Mt 15:4
# 27    28        Ex 21:17       Exodus     2    21    17         Mt 15:4
# 28    29       Isa 29:13       Isaiah    23    29    13       Mt 15:8,9
# 29    30         Ge 2:24      Genesis     1     2    24         Mt 19:5
# ..   ...             ...          ...   ...   ...   ...             ...
# 277  278       Hab 2:3,4     Habakkuk    35     2     3    Heb 10:37,38
# 278  279        Ge 47:31      Genesis     1    47    31       Heb 11:21
# 279  280      Pr 3:11,12     Proverbs    20     3    11      Heb 12:5,6
# 280  281     Ex 19:12,13       Exodus     2    19    12       Heb 12:20
# 281  282         De 9:19  Deuteronomy     5     9    19       Heb 12:21
# 282  283         Hag 2:6       Haggai    37     2     6       Heb 12:26
# 283  284         De 4:24  Deuteronomy     5     4    24       Heb 12:29
# 284  285         De 31:8  Deuteronomy     5    31     8        Heb 13:5
# 285  286         Jos 1:5       Joshua     6     1     5        Heb 13:5
# 286  287        Ps 118:6       Psalms    19   118     6        Heb 13:6
# 287  288        Le 19:18    Leviticus     3    19    18         Jas 2:8
# 288  289  Ex 20:13,14,15       Exodus     2    20    13        Jas 2:11
# 289  290         Ge 15:6      Genesis     1    15     6        Jas 2:23
# 290  291         Pr 3:34     Proverbs    20     3    34         Jas 4:6
# 291  292        Le 11:44    Leviticus     3    11    44        1Pe 1:16
# 292  293        Isa 40:6       Isaiah    23    40     6     1Pe 1:24,25
# 293  294       Isa 28:16       Isaiah    23    28    16         1Pe 2:6
# 294  295    Ps 118:22,23       Psalms    19   118    22         1Pe 2:7
# 295  296         Ex 19:6       Exodus     2    19     6         1Pe 2:9
# 296  297        Isa 53:9       Isaiah    23    53     9        1Pe 2:22
# 297  298      Isa 53:4,5       Isaiah    23    53     4        1Pe 2:24
# 298  299     Ps 34:12-16       Psalms    19    34    12  1Pe 3:10,11,12
# 299  300        Pr 10:12     Proverbs    20    10    12         1Pe 4:8
# 300  301        Pr 26:11     Proverbs    20    26    11        2Pe 2:22
# 301  302       Isa 49:10       Isaiah    23    49    10         Re 7:16
# 302  303        Isa 25:8       Isaiah    23    25     8         Re 7:17
# 303  304        Jer 10:6     Jeremiah    24    10     6         Re 15:4
# 304  305         Ps 86:9       Psalms    19    86     9         Re 15:4
# 305  306        Isa 21:9       Isaiah    23    21     9         Re 18:2
# 306  307        Jer 51:7     Jeremiah    24    51     7         Re 18:3
#
#         nt_book  nt_b  nt_c  nt_v
# 0       Matthew    40     1    23
# 1       Matthew    40     2     6
# 2       Matthew    40     2    15
# 3       Matthew    40     2    18
# 4       Matthew    40     3     3
# 5       Matthew    40     4     4
# 6       Matthew    40     4     6
# 7       Matthew    40     4     7
# 8       Matthew    40     4    10
# 9       Matthew    40     4    10
# 10      Matthew    40     4    15
# 11      Matthew    40     4    15
# 12      Matthew    40     5    21
# 13      Matthew    40     5    27
# 14      Matthew    40     5    38
# 15      Matthew    40     5    48
# 16      Matthew    40     7    23
# 17      Matthew    40     8    17
# 18      Matthew    40     9    13
# 19      Matthew    40    11    10
# 20      Matthew    40    12     7
# 21      Matthew    40    12    18
# 22      Matthew    40    12    18
# 23      Matthew    40    13    14
# 24      Matthew    40    13    35
# 25      Matthew    40    15     4
# 26      Matthew    40    15     4
# 27      Matthew    40    15     4
# 28      Matthew    40    15     8
# 29      Matthew    40    19     5
# ..          ...   ...   ...   ...
# 277     Hebrews    58    10    37
# 278     Hebrews    58    11    21
# 279     Hebrews    58    12     5
# 280     Hebrews    58    12    20
# 281     Hebrews    58    12    21
# 282     Hebrews    58    12    26
# 283     Hebrews    58    12    29
# 284     Hebrews    58    13     5
# 285     Hebrews    58    13     5
# 286     Hebrews    58    13     6
# 287       James    59     2     8
# 288       James    59     2    11
# 289       James    59     2    23
# 290       James    59     4     6
# 291     1 Peter    60     1    16
# 292     1 Peter    60     1    24
# 293     1 Peter    60     2     6
# 294     1 Peter    60     2     7
# 295     1 Peter    60     2     9
# 296     1 Peter    60     2    22
# 297     1 Peter    60     2    24
# 298     1 Peter    60     3    10
# 299     1 Peter    60     4     8
# 300     2 Peter    61     2    22
# 301  Revelation    66     7    16
# 302  Revelation    66     7    17
# 303  Revelation    66    15     4
# 304  Revelation    66    15     4
# 305  Revelation    66    18     2
# 306  Revelation    66    18     3
#
# [307 rows x 11 columns]

# %%
quotation_df.to_csv(QUOTATIONS_OUT_PATH, index=False)

# %%
quotation_ot_df = quotation_df.sort(["ot_b", "ot_c", "ot_v"])

# %%
quotation_ot_df
# Out:
#       ID             OT    ot_book  ot_b  ot_c  ot_v            NT  \
# 57    58        Ge 1:27    Genesis     1     1    27       Mr 10:6
# 265  266       Ge 2:2,3    Genesis     1     2     2       Heb 4:4
# 246  247         Ge 2:4    Genesis     1     2     4      Eph 5:31
# 219  220         Ge 2:7    Genesis     1     2     7     1Co 15:45
# 29    30        Ge 2:24    Genesis     1     2    24       Mt 19:5
# 58    59        Ge 2:24    Genesis     1     2    24       Mr 10:7
# 210  211        Ge 2:24    Genesis     1     2    24      1Co 6:16
# 123  124        Ge 12:1    Genesis     1    12     1        Ac 7:3
# 234  235        Ge 12:3    Genesis     1    12     3        Ga 3:8
# 158  159        Ge 15:5    Genesis     1    15     5       Ro 4:18
# 154  155        Ge 15:6    Genesis     1    15     6        Ro 4:3
# 289  290        Ge 15:6    Genesis     1    15     6      Jas 2:23
# 124  125    Ge 15:13,14    Genesis     1    15    13      Ac 7:6,7
# 15    16        Ge 17:1    Genesis     1    17     1       Mt 5:48
# 157  158        Ge 17:5    Genesis     1    17     5       Ro 4:17
# 156  157       Ge 17:10    Genesis     1    17    10       Ro 4:11
# 163  164       Ge 18:10    Genesis     1    18    10        Ro 9:9
# 241  242       Ge 21:10    Genesis     1    21    10       Ga 4:30
# 162  163       Ge 21:12    Genesis     1    21    12        Ro 9:7
# 269  270    Ge 22:16,17    Genesis     1    22    16      Heb 6:14
# 120  121       Ge 22:18    Genesis     1    22    18       Ac 3:25
# 239  240       Ge 22:18    Genesis     1    22    18       Ga 3:16
# 164  165       Ge 25:23    Genesis     1    25    23       Ro 9:12
# 278  279       Ge 47:31    Genesis     1    47    31     Heb 11:21
# 125  126     Ex 2:13,14     Exodus     2     2    13       Ac 7:26
# 128  129        Ex 2:14     Exodus     2     2    14       Ac 7:35
# 127  128  Ex 3:5,7,8,10     Exodus     2     3     5    Ac 7:33,34
# 39    40         Ex 3:6     Exodus     2     3     6      Mt 22:32
# 65    66         Ex 3:6     Exodus     2     3     6      Mr 12:26
# 126  127         Ex 3:6     Exodus     2     3     6       Ac 7:32
# ..   ...            ...        ...   ...   ...   ...           ...
# 306  307       Jer 51:7   Jeremiah    24    51     7       Re 18:3
# 175  176      Eze 20:11    Ezekiel    26    20    11       Ro 10:5
# 144  145      Eze 36:20    Ezekiel    26    36    20       Ro 2:24
# 169  170        Ho 1:10      Hosea    28     1    10       Ro 9:26
# 168  169        Ho 2:23      Hosea    28     2    23       Ro 9:25
# 18    19         Ho 6:6      Hosea    28     6     6       Mt 9:13
# 20    21         Ho 6:6      Hosea    28     6     6       Mt 12:7
# 2      3        Ho 11:1      Hosea    28    11     1       Mt 2:15
# 221  222       Ho 13:14      Hosea    28    13    14     1Co 15:55
# 115  116    Joe 2:28-32       Joel    29     2    28    Ac 2:17-21
# 178  179       Joe 2:32       Joel    29     2    32      Ro 10:13
# 1      2        Mic 5:2      Micah    33     5     2        Mt 2:6
# 180  181        Na 1:15      Nahum    34     1    15      Ro 10:15
# 138  139        Hab 1:5   Habakkuk    35     1     5      Ac 13:41
# 277  278      Hab 2:3,4   Habakkuk    35     2     3  Heb 10:37,38
# 142  143        Hab 2:4   Habakkuk    35     2     4       Ro 1:17
# 236  237        Hab 2:4   Habakkuk    35     2     4       Ga 3:11
# 282  283        Hag 2:6     Haggai    37     2     6     Heb 12:26
# 244  245       Zec 8:16  Zechariah    38     8    16      Eph 4:25
# 32    33        Zec 9:9  Zechariah    38     9     9       Mt 21:5
# 102  103        Zec 9:9  Zechariah    38     9     9  Joh 12:14,15
# 46    47      Zec 11:13  Zechariah    38    11    13    Mt 27:9,10
# 112  113      Zec 12:10  Zechariah    38    12    10     Joh 19:37
# 45    46       Zec 13:7  Zechariah    38    13     7      Mt 26:31
# 69    70       Zec 13:7  Zechariah    38    13     7      Mr 14:27
# 165  166      Mal 1:2,3    Malachi    39     1     2       Ro 9:13
# 19    20        Mal 3:1    Malachi    39     3     1      Mt 11:10
# 49    50        Mal 3:1    Malachi    39     3     1      Mr 1:2,3
# 82    83        Mal 3:1    Malachi    39     3     1       Lu 7:27
# 72    73      Mal 4:5,6    Malachi    39     4     5       Lu 1:17
#
#            nt_book  nt_b  nt_c  nt_v
# 57            Mark    41    10     6
# 265        Hebrews    58     4     4
# 246      Ephesians    49     5    31
# 219  1 Corinthians    46    15    45
# 29         Matthew    40    19     5
# 58            Mark    41    10     7
# 210  1 Corinthians    46     6    16
# 123           Acts    44     7     3
# 234      Galatians    48     3     8
# 158         Romans    45     4    18
# 154         Romans    45     4     3
# 289          James    59     2    23
# 124           Acts    44     7     6
# 15         Matthew    40     5    48
# 157         Romans    45     4    17
# 156         Romans    45     4    11
# 163         Romans    45     9     9
# 241      Galatians    48     4    30
# 162         Romans    45     9     7
# 269        Hebrews    58     6    14
# 120           Acts    44     3    25
# 239      Galatians    48     3    16
# 164         Romans    45     9    12
# 278        Hebrews    58    11    21
# 125           Acts    44     7    26
# 128           Acts    44     7    35
# 127           Acts    44     7    33
# 39         Matthew    40    22    32
# 65            Mark    41    12    26
# 126           Acts    44     7    32
# ..             ...   ...   ...   ...
# 306     Revelation    66    18     3
# 175         Romans    45    10     5
# 144         Romans    45     2    24
# 169         Romans    45     9    26
# 168         Romans    45     9    25
# 18         Matthew    40     9    13
# 20         Matthew    40    12     7
# 2          Matthew    40     2    15
# 221  1 Corinthians    46    15    55
# 115           Acts    44     2    17
# 178         Romans    45    10    13
# 1          Matthew    40     2     6
# 180         Romans    45    10    15
# 138           Acts    44    13    41
# 277        Hebrews    58    10    37
# 142         Romans    45     1    17
# 236      Galatians    48     3    11
# 282        Hebrews    58    12    26
# 244      Ephesians    49     4    25
# 32         Matthew    40    21     5
# 102           John    43    12    14
# 46         Matthew    40    27     9
# 112           John    43    19    37
# 45         Matthew    40    26    31
# 69            Mark    41    14    27
# 165         Romans    45     9    13
# 19         Matthew    40    11    10
# 49            Mark    41     1     2
# 82            Luke    42     7    27
# 72            Luke    42     1    17
#
# [307 rows x 11 columns]

# %%
quotation_ot_df.to_csv(QUOTATIONS_OT_OUT_PATH, index=False)

# %% [markdown]
# ## Some data analysis

# %%
Counter(quotation_df["ot_book"]).most_common()
# Out:
# [('Psalms', 83),
#  ('Isaiah', 62),
#  ('Deuteronomy', 41),
#  ('Exodus', 29),
#  ('Genesis', 24),
#  ('Leviticus', 12),
#  ('Jeremiah', 12),
#  ('Proverbs', 7),
#  ('Zechariah', 7),
#  ('Hosea', 6),
#  ('Malachi', 5),
#  ('Habakkuk', 4),
#  ('2 Samuel', 3),
#  ('1 Kings', 2),
#  ('Joel', 2),
#  ('Ezekiel', 2),
#  ('Job', 1),
#  ('Micah', 1),
#  ('Haggai', 1),
#  ('1 Samuel', 1),
#  ('Joshua', 1),
#  ('Nahum', 1)]

# %%
Counter(quotation_df["nt_book"]).most_common()
# Out:
# [('Romans', 62),
#  ('Matthew', 49),
#  ('Hebrews', 37),
#  ('Acts', 29),
#  ('Luke', 24),
#  ('Mark', 23),
#  ('1 Corinthians', 18),
#  ('John', 17),
#  ('2 Corinthians', 11),
#  ('Galatians', 10),
#  ('1 Peter', 9),
#  ('Revelation', 6),
#  ('Ephesians', 6),
#  ('James', 4),
#  ('1 Timothy', 1),
#  ('2 Peter', 1)]

# %%
ot_book_chapters = [" ".join(book_chapter) for book_chapter in zip(quotation_df["ot_book"],
                                                                   [str(c) for c in list(quotation_df["ot_c"])])]

# %%
nt_book_chapters = [" ".join(book_chapter) for book_chapter in zip(quotation_df["nt_book"],
                                                                   [str(c) for c in list(quotation_df["nt_c"])])]

# %%
Counter(ot_book_chapters).most_common(30)
# Out:
# [('Exodus 20', 9),
#  ('Deuteronomy 5', 8),
#  ('Isaiah 53', 8),
#  ('Psalms 118', 8),
#  ('Psalms 110', 8),
#  ('Isaiah 40', 7),
#  ('Leviticus 19', 7),
#  ('Deuteronomy 6', 7),
#  ('Genesis 2', 6),
#  ('Psalms 22', 5),
#  ('Deuteronomy 32', 5),
#  ('Deuteronomy 25', 5),
#  ('Psalms 69', 5),
#  ('Isaiah 6', 5),
#  ('Jeremiah 31', 4),
#  ('Psalms 2', 4),
#  ('Exodus 3', 4),
#  ('Genesis 15', 4),
#  ('Psalms 95', 4),
#  ('Isaiah 28', 4),
#  ('Isaiah 29', 4),
#  ('Isaiah 52', 4),
#  ('Isaiah 49', 3),
#  ('Isaiah 42', 3),
#  ('Jeremiah 7', 3),
#  ('Genesis 22', 3),
#  ('Psalms 8', 3),
#  ('Psalms 6', 3),
#  ('Malachi 3', 3),
#  ('Proverbs 3', 3)]

# %%
Counter(nt_book_chapters).most_common(30)
# Out:
# [('Romans 9', 12),
#  ('Romans 10', 11),
#  ('Romans 3', 9),
#  ('Acts 7', 9),
#  ('Matthew 4', 7),
#  ('Hebrews 1', 7),
#  ('Acts 13', 7),
#  ('Mark 12', 6),
#  ('Matthew 21', 6),
#  ('1 Corinthians 15', 6),
#  ('Luke 4', 6),
#  ('Galatians 3', 6),
#  ('Romans 15', 6),
#  ('Romans 11', 6),
#  ('Romans 4', 5),
#  ('Matthew 22', 5),
#  ('Mark 7', 5),
#  ('Hebrews 2', 5),
#  ('2 Corinthians 6', 5),
#  ('1 Peter 2', 5),
#  ('Hebrews 12', 5),
#  ('John 19', 4),
#  ('Acts 2', 4),
#  ('Matthew 5', 4),
#  ('Matthew 15', 4),
#  ('Hebrews 10', 4),
#  ('Mark 11', 3),
#  ('Mark 10', 3),
#  ('Luke 20', 3),
#  ('John 15', 3)]

# %% [markdown]
# ## Include actual text

# %%
text_all = pandas.read_csv(TEXT_PATH)

# %%
text_dict = dict(zip(text_all["id"], text_all["t"]))

# %%
ot_ids = [10**6*t[0] + 10**3*t[1] + t[2] for t in
          zip(quotation_df["ot_b"], quotation_df["ot_c"], quotation_df["ot_v"])]
ot_verse_text = [text_dict[ot_id] for ot_id in ot_ids]

# %%
nt_ids = [10**6*t[0] + 10**3*t[1] + t[2] for t in
          zip(quotation_df["nt_b"], quotation_df["nt_c"], quotation_df["nt_v"])]
nt_verse_text = [text_dict[nt_id] for nt_id in nt_ids]

# %%
quotation_text_df = pandas.DataFrame({"nt_ref": quotation_df["NT"], "ot_ref": quotation_df["OT"],
                                      "ot_text": ot_verse_text, "nt_text": nt_verse_text})

# %%
ot_ids_2 = [10**6*t[0] + 10**3*t[1] + t[2] for t in
            zip(quotation_ot_df["ot_b"], quotation_ot_df["ot_c"], quotation_ot_df["ot_v"])]
ot_verse_text_2 = [text_dict[ot_id] for ot_id in ot_ids_2]

# %%
nt_ids_2 = [10**6*t[0] + 10**3*t[1] + t[2] for t in
            zip(quotation_ot_df["nt_b"], quotation_ot_df["nt_c"], quotation_ot_df["nt_v"])]
nt_verse_text_2 = [text_dict[nt_id] for nt_id in nt_ids_2]

# %%
quotation_text_df_2 = pandas.DataFrame({"nt_ref": quotation_ot_df["NT"], "ot_ref": quotation_ot_df["OT"],
                                        "ot_text": ot_verse_text_2, "nt_text": nt_verse_text_2})
quotation_text_df_2 = quotation_text_df_2[["ot_ref", "ot_text", "nt_ref", "nt_text"]]

# %%
quotation_text_df.to_csv(QUOTATIONS_TEXT_OUT_PATH, index=False)
quotation_text_df_2.to_csv(QUOTATIONS_TEXT_OT_OUT_PATH, index=False)

# %%
# Pretty CSVs are better for viewing on GitHub preview
quotation_text_df[["nt_ref", "ot_ref", "ot_text"]].to_csv(
    os.path.join(OUTPUT_DIR, "quotations_text_pretty.csv"), index=False)
quotation_text_df_2[["ot_ref", "nt_ref", "nt_text"]].to_csv(
    os.path.join(OUTPUT_DIR, "quotations_ot_text_pretty.csv"), index=False)

# %%
quotation_text_df
# Out:
#              nt_ref                                            nt_text  \
# 0           Mt 1:23  Behold, a virgin shall be with child, and shal...
# 1            Mt 2:6  And thou Bethlehem, in the land of Juda, art n...
# 2           Mt 2:15  And was there until the death of Herod: that i...
# 3           Mt 2:18  In Rama was there a voice heard, lamentation, ...
# 4            Mt 3:3  For this is he that was spoken of by the proph...
# 5            Mt 4:4  But he answered and said, It is written, Man s...
# 6            Mt 4:6  And saith unto him, If thou be the Son of God,...
# 7            Mt 4:7  Jesus said unto him, It is written again, Thou...
# 8           Mt 4:10  Then saith Jesus unto him, Get thee hence, Sat...
# 9           Mt 4:10  Then saith Jesus unto him, Get thee hence, Sat...
# 10       Mt 4:15,16  The land of Zabulon, and the land of Nephthali...
# 11       Mt 4:15,16  The land of Zabulon, and the land of Nephthali...
# 12          Mt 5:21  Ye have heard that it was said of them of old ...
# 13          Mt 5:27  Ye have heard that it was said by them of old ...
# 14          Mt 5:38  Ye have heard that it hath been said, An eye f...
# 15          Mt 5:48  Be ye therefore perfect, even as your Father w...
# 16          Mt 7:23  And then will I profess unto them, I never kne...
# 17          Mt 8:17  That it might be fulfilled which was spoken by...
# 18          Mt 9:13  But go ye and learn what that meaneth, I will ...
# 19         Mt 11:10  For this is he, of whom it is written, Behold,...
# 20          Mt 12:7  But if ye had known what this meaneth, I will ...
# 21         Mt 12:18  Behold my servant, whom I have chosen; my belo...
# 22      Mt 12:18-21  Behold my servant, whom I have chosen; my belo...
# 23         Mt 13:14  And in them is fulfilled the prophecy of Esaia...
# 24         Mt 13:35  That it might be fulfilled which was spoken by...
# 25          Mt 15:4  For God commanded, saying, Honour thy father a...
# 26          Mt 15:4  For God commanded, saying, Honour thy father a...
# 27          Mt 15:4  For God commanded, saying, Honour thy father a...
# 28        Mt 15:8,9  This people draweth nigh unto me with their mo...
# 29          Mt 19:5  And said, For this cause shall a man leave fat...
# ..              ...                                                ...
# 277    Heb 10:37,38  For yet a little while, and he that shall come...
# 278       Heb 11:21  By faith Jacob, when he was a dying, blessed b...
# 279      Heb 12:5,6  And ye have forgotten the exhortation which sp...
# 280       Heb 12:20  (For they could not endure that which was comm...
# 281       Heb 12:21  And so terrible was the sight, that Moses said...
# 282       Heb 12:26  Whose voice then shook the earth: but now he h...
# 283       Heb 12:29                   For our God is a consuming fire.
# 284        Heb 13:5  Let your conversation be without covetousness;...
# 285        Heb 13:5  Let your conversation be without covetousness;...
# 286        Heb 13:6  So that we may boldly say, The Lord is my help...
# 287         Jas 2:8  If ye fulfil the royal law according to the sc...
# 288        Jas 2:11  For he that said, Do not commit adultery, said...
# 289        Jas 2:23  And the scripture was fulfilled which saith, A...
# 290         Jas 4:6  But he giveth more grace. Wherefore he saith, ...
# 291        1Pe 1:16  Because it is written, Be ye holy; for I am holy.
# 292     1Pe 1:24,25  For all flesh is as grass, and all the glory o...
