# %%
import os
import csv
import pandas

# %%
# %pwd
# Out:
# u'/Users/brian/code/bible/jupyter'

# %%
DATA_DIR = "/Users/brian/code/bible/data"
OUTPUT_DIR = "/Users/brian/code/bible/output"
TEXT_PATH = os.path.join(DATA_DIR, "bible-corpus/t_kjv.csv")
GENRE_PATH = os.path.join(DATA_DIR, "bible-corpus/key_genre_english.csv")
BOOK_PATH = os.path.join(DATA_DIR, "bible-corpus/key_english.csv")
OUT_DF_PATH = os.path.join(OUTPUT_DIR, "books_summary.csv")

# %%
genre_df = pandas.read_csv(GENRE_PATH)
genre_dict = dict(zip(genre_df["g"], genre_df["n"]))

# %%
genre_dict
# Out:
# {1: 'Law',
#  2: 'History',
#  3: 'Wisdom',
#  4: 'Prophets',
#  5: 'Gospels',
#  6: 'Acts',
#  7: 'Epistles',
#  8: 'Apocalyptic'}

# %%
book_df = pandas.read_csv(BOOK_PATH)
book_df.rename(index=str, columns={"n": "name", "t": "testament"}, inplace=True)
book_df["genre"] = [genre_dict[k] for k in book_df["g"]]

book_dict = dict(zip(book_df["b"], book_df["name"]))
book_genre_dict = dict(zip(book_df["name"], book_df["g"]))

# %%
book_df
# Out:
#      b             name testament  g        genre
# 0    1          Genesis        OT  1          Law
# 1    2           Exodus        OT  1          Law
# 2    3        Leviticus        OT  1          Law
# 3    4          Numbers        OT  1          Law
# 4    5      Deuteronomy        OT  1          Law
# 5    6           Joshua        OT  2      History
# 6    7           Judges        OT  2      History
# 7    8             Ruth        OT  2      History
# 8    9         1 Samuel        OT  2      History
# 9   10         2 Samuel        OT  2      History
# 10  11          1 Kings        OT  2      History
# 11  12          2 Kings        OT  2      History
# 12  13     1 Chronicles        OT  2      History
# 13  14     2 Chronicles        OT  2      History
# 14  15             Ezra        OT  2      History
# 15  16         Nehemiah        OT  2      History
# 16  17           Esther        OT  2      History
# 17  18              Job        OT  3       Wisdom
# 18  19           Psalms        OT  3       Wisdom
# 19  20         Proverbs        OT  3       Wisdom
# 20  21     Ecclesiastes        OT  3       Wisdom
# 21  22  Song of Solomon        OT  3       Wisdom
# 22  23           Isaiah        OT  4     Prophets
# 23  24         Jeremiah        OT  4     Prophets
# 24  25     Lamentations        OT  4     Prophets
# 25  26          Ezekiel        OT  4     Prophets
# 26  27           Daniel        OT  4     Prophets
# 27  28            Hosea        OT  4     Prophets
# 28  29             Joel        OT  4     Prophets
# 29  30             Amos        OT  4     Prophets
# ..  ..              ...       ... ..          ...
# 36  37           Haggai        OT  4     Prophets
# 37  38        Zechariah        OT  4     Prophets
# 38  39          Malachi        OT  4     Prophets
# 39  40          Matthew        NT  5      Gospels
# 40  41             Mark        NT  5      Gospels
# 41  42             Luke        NT  5      Gospels
# 42  43             John        NT  5      Gospels
# 43  44             Acts        NT  6         Acts
# 44  45           Romans        NT  7     Epistles
# 45  46    1 Corinthians        NT  7     Epistles
# 46  47    2 Corinthians        NT  7     Epistles
# 47  48        Galatians        NT  7     Epistles
# 48  49        Ephesians        NT  7     Epistles
# 49  50      Philippians        NT  7     Epistles
# 50  51       Colossians        NT  7     Epistles
# 51  52  1 Thessalonians        NT  7     Epistles
# 52  53  2 Thessalonians        NT  7     Epistles
# 53  54        1 Timothy        NT  7     Epistles
# 54  55        2 Timothy        NT  7     Epistles
# 55  56            Titus        NT  7     Epistles
# 56  57         Philemon        NT  7     Epistles
# 57  58          Hebrews        NT  7     Epistles
# 58  59            James        NT  7     Epistles
# 59  60          1 Peter        NT  7     Epistles
# 60  61          2 Peter        NT  7     Epistles
# 61  62           1 John        NT  7     Epistles
# 62  63           2 John        NT  7     Epistles
# 63  64           3 John        NT  7     Epistles
# 64  65             Jude        NT  7     Epistles
# 65  66       Revelation        NT  8  Apocalyptic
#
# [66 rows x 5 columns]

# %%
text_all = pandas.read_csv(TEXT_PATH)

# %%
text_all["words"] = [len(verse.split(" ")) for verse in text_all["t"]]

# %%
text_all.head()
# Out:
#         id  b  c  v                                                  t  words
# 0  1001001  1  1  1  In the beginning God created the heaven and th...     10
# 1  1001002  1  1  2  And the earth was without form, and void; and ...     29
# 2  1001003  1  1  3  And God said, Let there be light: and there wa...     11
# 3  1001004  1  1  4  And God saw the light, that it was good: and G...     17
# 4  1001005  1  1  5  And God called the light Day, and the darkness...     22

# %%
book_df["chapters"] = text_all.groupby("b")["c"].nunique().tolist()
book_df["verses"] = text_all.groupby("b").size().tolist()
book_df["words_kjv"] = text_all.groupby("b")["words"].sum().tolist()

# %%
book_df
# Out:
#      b             name testament  g        genre  chapters  verses  words_kjv
# 0    1          Genesis        OT  1          Law        50    1533      38265
# 1    2           Exodus        OT  1          Law        40    1213      32684
# 2    3        Leviticus        OT  1          Law        27     859      24543
# 3    4          Numbers        OT  1          Law        36    1288      32895
# 4    5      Deuteronomy        OT  1          Law        34     959      28352
# 5    6           Joshua        OT  2      History        24     658      18852
# 6    7           Judges        OT  2      History        21     618      18966
# 7    8             Ruth        OT  2      History         4      85       2574
# 8    9         1 Samuel        OT  2      History        31     810      25047
# 9   10         2 Samuel        OT  2      History        24     695      20599
# 10  11          1 Kings        OT  2      History        22     816      24512
# 11  12          2 Kings        OT  2      History        25     719      23521
# 12  13     1 Chronicles        OT  2      History        29     942      20365
# 13  14     2 Chronicles        OT  2      History        36     822      26069
# 14  15             Ezra        OT  2      History        10     280       7440
# 15  16         Nehemiah        OT  2      History        13     406      10480
# 16  17           Esther        OT  2      History        10     167       5630
# 17  18              Job        OT  3       Wisdom        42    1070      18098
# 18  19           Psalms        OT  3       Wisdom       150    2461      42684
# 19  20         Proverbs        OT  3       Wisdom        31     915      15038
# 20  21     Ecclesiastes        OT  3       Wisdom        12     222       5580
# 21  22  Song of Solomon        OT  3       Wisdom         8     117       2658
# 22  23           Isaiah        OT  4     Prophets        66    1292      37039
# 23  24         Jeremiah        OT  4     Prophets        52    1364      42654
# 24  25     Lamentations        OT  4     Prophets         5     154       3411
# 25  26          Ezekiel        OT  4     Prophets        48    1273      39401
# 26  27           Daniel        OT  4     Prophets        12     357      11603
# 27  28            Hosea        OT  4     Prophets        14     197       5174
# 28  29             Joel        OT  4     Prophets         3      73       2033
# 29  30             Amos        OT  4     Prophets         9     146       4216
# ..  ..              ...       ... ..          ...       ...     ...        ...
# 36  37           Haggai        OT  4     Prophets         2      38       1130
# 37  38        Zechariah        OT  4     Prophets        14     211       6443
# 38  39          Malachi        OT  4     Prophets         4      55       1781
# 39  40          Matthew        NT  5      Gospels        28    1071      23684
# 40  41             Mark        NT  5      Gospels        16     678      15166
# 41  42             Luke        NT  5      Gospels        24    1151      25939
# 42  43             John        NT  5      Gospels        21     879      19094
# 43  44             Acts        NT  6         Acts        28    1007      24246
# 44  45           Romans        NT  7     Epistles        16     433       9422
# 45  46    1 Corinthians        NT  7     Epistles        16     437       9462
# 46  47    2 Corinthians        NT  7     Epistles        13     257       6065
# 47  48        Galatians        NT  7     Epistles         6     149       3084
# 48  49        Ephesians        NT  7     Epistles         6     155       3022
# 49  50      Philippians        NT  7     Epistles         4     104       2183
# 50  51       Colossians        NT  7     Epistles         4      95       1979
# 51  52  1 Thessalonians        NT  7     Epistles         5      89       1837
# 52  53  2 Thessalonians        NT  7     Epistles         3      47       1022
# 53  54        1 Timothy        NT  7     Epistles         6     113       2244
# 54  55        2 Timothy        NT  7     Epistles         4      83       1666
# 55  56            Titus        NT  7     Epistles         3      46        896
# 56  57         Philemon        NT  7     Epistles         1      25        430
# 57  58          Hebrews        NT  7     Epistles        13     303       6897
# 58  59            James        NT  7     Epistles         5     108       2304
# 59  60          1 Peter        NT  7     Epistles         5     105       2475
# 60  61          2 Peter        NT  7     Epistles         3      61       1553
# 61  62           1 John        NT  7     Epistles         5     105       2516
# 62  63           2 John        NT  7     Epistles         1      13        298
# 63  64           3 John        NT  7     Epistles         1      15        295
# 64  65             Jude        NT  7     Epistles         1      25        608
# 65  66       Revelation        NT  8  Apocalyptic        22     404      11995
#
# [66 rows x 8 columns]

# %%
print "The KJV contains", sum(book_df["chapters"]), "chapters,", \
    sum(book_df["verses"]), "verses, and", \
    sum(book_df["words_kjv"]), "words"
# Out:
# The KJV contains 1189 chapters, 31103 verses, and 789635 words

# %%
book_df.to_csv(OUT_DF_PATH, index=False)

# %% [markdown]
# ## Visualization time

# %%
import plotly
plotly.__version__
# Out:
# '3.3.0'

# %%
import plotly.plotly as py
import plotly.graph_objs as go

# %%
criteria = ["chapters", "verses", "words_kjv"]
pretty_criteria = ["chapters", "verses", "words (KJV)"]
colors = ["red", "green", "blue"]
height_px = 800

# %%
index = 0
criterion = criteria[index]
pretty_criterion = pretty_criteria[index]
book_indices = book_df[criterion].argsort()

trace1 = {"x": book_df[criterion][book_indices],
          "y": book_df["name"][book_indices],
          "marker": {"color": colors[index], "size": 12},
          "mode": "markers",
          "name": pretty_criterion,
          "type": "scatter"
}

data = [trace1]
layout = {"title": "Bible Books by Length",
          "xaxis": {"title": "Number of " + pretty_criterion},
          "height": height_px
         }

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='bible_dot_plot_' + criterion)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~brianzhang01/6.embed" height="800px" width="100%"></iframe>

# %%
index = 1
criterion = criteria[index]
pretty_criterion = pretty_criteria[index]
book_indices = book_df[criterion].argsort()

trace1 = {"x": book_df[criterion][book_indices],
          "y": book_df["name"][book_indices],
          "marker": {"color": colors[index], "size": 12},
          "mode": "markers",
          "name": pretty_criterion,
          "type": "scatter"
}

data = [trace1]
layout = {"title": "Bible Books by Length",
          "xaxis": {"title": "Number of " + pretty_criterion},
          "height": height_px
         }

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='bible_dot_plot_' + criterion)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~brianzhang01/8.embed" height="800px" width="100%"></iframe>

# %%
index = 2
criterion = criteria[index]
pretty_criterion = pretty_criteria[index]
book_indices = book_df[criterion].argsort()

trace1 = {"x": book_df[criterion][book_indices],
          "y": book_df["name"][book_indices],
          "marker": {"color": colors[index], "size": 12},
          "mode": "markers",
          "name": pretty_criterion,
          "type": "scatter"
}

data = [trace1]
layout = {"title": "Bible Books by Length",
          "xaxis": {"title": "Number of " + pretty_criterion},
          "height": height_px
         }

fig = go.Figure(data=data, layout=layout)
py.iplot(fig, filename='bible_dot_plot_' + criterion)
# Out:
# <iframe id="igraph" scrolling="no" style="border:none;" seamless="seamless" src="https://plot.ly/~brianzhang01/10.embed" height="800px" width="100%"></iframe>
